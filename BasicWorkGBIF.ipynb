# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('examples/GBIF_World.csv', sep = ",")
df.head()
# Out:
#           gbifID                            datasetKey  \
# 0     3395912434  84d26682-f762-11e1-a439-00145eb45e9a
# 1     3393147503  b124e1e0-4755-430f-9eab-894f25a9b59c
# 2     3393037337  b124e1e0-4755-430f-9eab-894f25a9b59c
# 3     3389784557  6ac3f774-d9fb-4796-b3e9-92bf6c81c084
# 4     3389781651  6ac3f774-d9fb-4796-b3e9-92bf6c81c084
# ...          ...                                   ...
# 6461    42433821  832282e0-f762-11e1-a439-00145eb45e9a
# 6462    39657802  83435394-f762-11e1-a439-00145eb45e9a
# 6463    36740417  b929f23d-290f-4e85-8f17-764c55b3b284
# 6464    36739353  b929f23d-290f-4e85-8f17-764c55b3b284
# 6465    31231121  835e62e2-f762-11e1-a439-00145eb45e9a
#
#                                            occurrenceID kingdom  \
# 0     https://svampe.databasen.org/observations/1024...   Fungi
# 1         urn:uuid:df80f278-4957-47cd-8157-1425fd1ee3d8   Fungi
# 2         urn:uuid:41a99575-8ce8-413f-ba64-95c217339d60   Fungi
# ...

# %%
df. describe()
# Out:
#              gbifID  individualCount  decimalLatitude  decimalLongitude  \
# count  6.466000e+03       601.000000      4818.000000       4818.000000
# mean   2.286643e+09         2.206323        30.082042         -8.886388
# std    9.467859e+08         7.077949        31.737285         81.018516
# min    3.123112e+07         1.000000       -67.585600       -173.502000
# 25%    2.016257e+09         1.000000        31.237000        -73.974700
# 50%    2.568947e+09         1.000000        40.788000         -1.175062
# 75%    2.941316e+09         1.000000        52.150000          8.104832
# max    3.395912e+09       101.000000        82.600000        176.828154
#
#        coordinateUncertaintyInMeters  coordinatePrecision    elevation  \
# count                    2266.000000             2.000000    28.000000
# mean                     4234.132392             0.016667   574.517857
# std                      4667.427751             0.000000   555.650394
# ...

# %%
x = df['year'].array
#Eliminación de NaN
x = x[np.logical_not(np.isnan(x))]
x = x.astype(int)
x
# Out:
# array([2021, 2021, 2021, ..., 2003, 1987, 1910])

# %%
intervalos = range(1860, max(x)+2) #calculamos los extremos de los intervalos
año = list(range(1860, 2021, 20))
plt.style.use('ggplot')
#plt.style.use('fivethirtyeight')
plt.hist(x=x, bins=intervalos, color='blue', rwidth=0.85)
plt.title('Entomophthorales reportados en GBIF')
plt.xlabel('Año')
plt.ylabel('Frecuencia')
plt.xticks(año,rotation=45)
plt.savefig("Histograma.png",dpi=300)

# %%
# Para variables discretas
pd.value_counts(df['species'])
# Out:
# Entomophthora muscae         1320
# Massospora cicadina           513
# Conidiobolus coronatus        369
# Conidiobolus firmipilleus     276
# Zoophthora aphidis            178
#                              ...
# Completoria complens            1
# Neozygites turbinatus           1
# Entomophthora helvetica         1
# Entomophthora egressa           1
# Batkoa cercopidis               1
# Name: species, Length: 145, dtype: int64

# %%
100 * df['species'].value_counts() / len(df['species'])
# Out:
# Entomophthora muscae         20.414476
# Massospora cicadina           7.933808
# Conidiobolus coronatus        5.706774
# Conidiobolus firmipilleus     4.268481
# Zoophthora aphidis            2.752861
#                                ...
# Completoria complens          0.015466
# Neozygites turbinatus         0.015466
# Entomophthora helvetica       0.015466
# Entomophthora egressa         0.015466
# Batkoa cercopidis             0.015466
# Name: species, Length: 145, dtype: float64

# %%
df_Mex = pd.read_csv('C:/Users/Octavio/Desktop/code/Diversity/GBIF_Mexico.csv', sep = ",")
# Out:
#          gbifID                            datasetKey  \
# 0    3384870287  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1    3384787581  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2    3384001242  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3    3351840904  d8cd16ba-bb74-4420-821e-083f2bac17c2
# 4    3351597890  d8cd16ba-bb74-4420-821e-083f2bac17c2
# ..          ...                                   ...
# 593    42648279  832282e0-f762-11e1-a439-00145eb45e9a
# 594    42648270  832282e0-f762-11e1-a439-00145eb45e9a
# 595    42648261  832282e0-f762-11e1-a439-00145eb45e9a
# 596    42511530  832282e0-f762-11e1-a439-00145eb45e9a
# 597    42403596  832282e0-f762-11e1-a439-00145eb45e9a
#
#                                           occurrenceID kingdom  \
# 0    https://www.inaturalist.org/observations/96164673   Fungi
# 1    https://www.inaturalist.org/observations/96486635   Fungi
# 2    https://www.inaturalist.org/observations/96116758   Fungi
# ...

# %%
x_Mex = df_Mex['year'].array
#Eliminación de NaN
x_Mex = x_Mex[np.logical_not(np.isnan(x_Mex))]
x_Mex = x_Mex.astype(int)
x_Mex.head()
# Out:
# array([2021, 2021, 2021, 2014, 2014, 2014, 2014, 2016, 2011, 2011, 2011,
#        2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2014, 2014, 2014,
#        2014, 2014, 2014, 2015, 2018, 2017, 1988, 2002, 1987, 1987, 1992,
#        1989, 2015, 2014, 1992, 2018, 2015, 2014, 1988, 1988, 2015, 1988,
#        1988, 1988, 1988, 2012, 2014, 1991, 2012, 1991, 2015, 1991, 2014,
#        1988, 1991, 2015, 1988, 1988, 2013, 2012, 2012, 2014, 1991, 2012,
#        1988, 1988, 2014, 2012, 1991, 2013, 2012, 2012, 2013, 2011, 2012,
#        2012, 2012, 2013, 2012, 2012, 2012, 2015, 2013, 2012, 2009, 2011,
#        1987, 2014, 2012, 2014, 1996, 1996, 2011, 2015, 1988, 2011, 2012,
#        2011, 2012, 1996, 1996, 1988, 2012, 2011, 2011, 2011, 1996, 1996,
#        1993, 1996, 2012, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011,
#        2011, 2008, 2011, 2011, 2011, 2010, 2011, 2005, 2011, 2008, 2004,
#        2004, 2004, 1989, 2015, 2015, 2014, 2015, 1992, 1987, 1987, 2002,
# ...

# %%
intervalos_Mex = range(1950, max(x_Mex)+2) #calculamos los extremos de los intervalos
año_Mex = list(range(1950, 2024, 10))
# se le quito el +2
plt.style.use('ggplot')
#plt.style.use('fivethirtyeight')
plt.hist(x=x_Mex, bins=intervalos_Mex, color='red', rwidth=0.85)
plt.title('Reportes de Entomopatógenos de México en GBIF')
plt.xlabel('Año')
plt.ylabel('Frecuencia')
plt.xticks(año_Mex,rotation=45)
plt.savefig("Histograma_Mex.png",dpi=300)

# %%
# Para variables discretas
pd.value_counts(df_Mex['species'])
# Out:
# Beauveria bassiana              274
# Metarhizium anisopliae          122
# Ophiocordyceps entomorrhiza      67
# Cordyceps militaris              50
# Hirsutella citriformis           30
# Erynia radicans                   7
# Conidiobolus coronatus            7
# Ophiocordyceps gracilis           7
# Akanthomyces lecanii              6
# Ophiocordyceps melolonthae        5
# Metarhizium rileyi                5
# Simplicillium lanosoniveum        5
# Ophiocordyceps gracilioides       4
# Entomophthora muscae              3
# Aspergillus aculeatus             2
# Ophiocordyceps sphecocephala      2
# Cordyceps fumosorosea             1
# Ophiocordyceps stylophora         1
# Name: species, dtype: int64

# %%
100 * df_Mex['species'].value_counts() / len(df_Mex['species'])
# Out:
# Beauveria bassiana              45.819398
# Metarhizium anisopliae          20.401338
# Ophiocordyceps entomorrhiza     11.204013
# Cordyceps militaris              8.361204
# Hirsutella citriformis           5.016722
# Erynia radicans                  1.170569
# Conidiobolus coronatus           1.170569
# Ophiocordyceps gracilis          1.170569
# Akanthomyces lecanii             1.003344
# Ophiocordyceps melolonthae       0.836120
# Metarhizium rileyi               0.836120
# Simplicillium lanosoniveum       0.836120
# Ophiocordyceps gracilioides      0.668896
# Entomophthora muscae             0.501672
# Aspergillus aculeatus            0.334448
# Ophiocordyceps sphecocephala     0.334448
# Cordyceps fumosorosea            0.167224
# Ophiocordyceps stylophora        0.167224
# Name: species, dtype: float64

# %%
plot = (pd.value_counts(df_Mex['species'])).plot(
kind='bar', title='Especies de Entomopatógenos de México en GBIF')
plt.savefig("Especies_Mex.png",dpi=300)

# %% [markdown]
# # Guardar y crear archivos csv

# %%
# si es un data frame
# df_numeros.to_csv('numeros.csv', header=False, index=False)

# si es un array
Filo = df_Mex['phylum'].array
Clase = df_Mex['class'].array
Orden = df_Mex['order'].array
Familia = df_Mex['family'].array
Genero = df_Mex['genus'].array
Especie = df_Mex['species'].array

#Para la localidad
Loc1 = df_Mex['stateProvince'].array
Loc2 = df_Mex['locality'].array

Estados = ('Aguascalientes', 'Baja California', 'Baja California Sur', 'Campeche', 'Coahuila', 'Colima', 'Chiapas', 'Chihuahua', 'Durango', 'Distrito Federal', 'Guanajuato', 'Guerrero', 'Hidalgo', 'Jalisco', 'Mexico', 'Michoacan', 'Morelos', 'Nayarit', 'Nuevo Leon', 'Oaxaca', 'Puebla', 'Queretaro', 'Quintana Roo', 'San Luis Potosi', 'Sinaloa', 'Sonora', 'Tabasco', 'Tamaulipas', 'Tlaxcala', 'Veracruz', 'Yucatán', 'Zacatecas')

# %%
# Creacción de un array que contenga la localidad
Localidad = []
i = 0
while i<np.size(Loc1):
    if Loc1[i] in Estados:
        print (Loc1[i])
        Localidad.append(Loc1[i])
    else:
        print (Loc2[i])
        Localidad.append(Loc2[i])
    i=i+1
# Out:
# Morelos
# Morelos
# Jalisco
# nan
# Minatitlan, Colima
# Comala, Colima
# Comala, Colima
# nan
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# Sinaloa
# nan
# nan
# Minatitlan, Colima
# nan
# Minatitlan, Colima
# Minatitlan, Colima
# Aguascalientes
# nan
# Chiapas
# Cuauhtemoc, Colima
# Cuauhtemoc, Colima
# Colima
# Cuauhtemoc, Colima
# Colima
# Colima
# Comala, Colima
# Minatitlan, Colima
# Colima
# Chihuahua
# Comala, Colima
# Comala, Colima
# Colima
# Tecoman, Colima
# Comala, Colima
# Colima
# Colima
# Tecoman, Colima
# Colima
# Cuauhtemoc, Colima
# Comala, Colima
# Colima
# Comala, Colima
# Colima
# Comala, Colima
# Colima
# Comala, Colima
# Colima
# Colima
# Comala, Colima
# Colima
# Colima
# Comala, Colima
# Minatitlan, Colima
# Cuauhtemoc, Colima
# Comala, Colima
# Colima
# Comala, Colima
# Colima
# Colima
# Comala, Colima
# Minatitlan, Colima
# Colima
# nan
# Comala, Colima
# Minatitlan, Colima
# Minatitlan, colima
# ...

# %%
#Construcción de un data frame con los parametros extraidos
df_bd = pd.DataFrame()
df_bd['Filo'] = Filo
df_bd['Clase'] = Clase
df_bd['Orden'] = Orden
df_bd['Familia'] = Familia
df_bd['Genero'] = Genero
df_bd['Especie'] = Especie
df_bd['Localidad'] = Localidad

df_bd
# Out:
#                     Filo                 Clase             Orden  \
# 0             Ascomycota       Sordariomycetes       Hypocreales
# 1             Ascomycota       Sordariomycetes       Hypocreales
# 2    Entomophthoromycota  Entomophthoromycetes  Entomophthorales
# 3             Ascomycota       Sordariomycetes       Hypocreales
# 4             Ascomycota       Sordariomycetes       Hypocreales
# ..                   ...                   ...               ...
# 593           Ascomycota       Sordariomycetes       Hypocreales
# 594           Ascomycota       Sordariomycetes       Hypocreales
# 595           Ascomycota       Sordariomycetes       Hypocreales
# 596           Ascomycota       Sordariomycetes       Hypocreales
# 597           Ascomycota       Sordariomycetes       Hypocreales
#
#                   Familia          Genero                      Especie  \
# 0    Ophiocordycipitaceae  Ophiocordyceps  Ophiocordyceps gracilioides
# ...

# %%
# Guadar el data frame en un archivo csv
df_bd.to_csv('EspeciesMexLite.csv')
